# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.facecolor'] = 'white'


ds = pd.read_csv("././././flights/train.csv")

ds.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
ds.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %%
colums = ds.columns
print(colums)
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
column_ini = ds['Customer Type']

column_sum = column_ini.describe()
print(column_sum)
column_ini.count()
column_ini.value_counts()
# Out:
# count             103904
# unique                 2
# top       Loyal Customer
# freq               84923
# Name: Customer Type, dtype: object
# Loyal Customer       84923
# disloyal Customer    18981
# Name: Customer Type, dtype: int64

# %%
ds.loc[0:5,'Gender':'Class']
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    Male  disloyal Customer   25  Business travel  Business
# 2  Female     Loyal Customer   26  Business travel  Business
# 3  Female     Loyal Customer   25  Business travel  Business
# 4    Male     Loyal Customer   61  Business travel  Business
# 5  Female     Loyal Customer   26  Personal Travel       Eco

# %%
working_column = ds['Customer Type']
working_column_unique = working_column.unique()
working_column_unique.sort()

col_summary = working_column.describe()
print(col_summary)
# Out:
# count             103904
# unique                 2
# top       Loyal Customer
# freq               84923
# Name: Customer Type, dtype: object

# %%
ds['satisfaction'].value_counts()
# Out:
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: satisfaction, dtype: int64

# %%
ds.plot(kind="scatter", x="Inflight entertainment", y="Inflight service")
# Out:
# <AxesSubplot:xlabel='Inflight entertainment', ylabel='Inflight service'>

# %%
sns.FacetGrid(ds, hue="Customer Type", size=5) \
   .map(plt.scatter, "Checkin service", "Inflight service") \
   .add_legend()
# Out:
# /home/joelsilva/Documents/Uni/sextoSemestre/AOOP/tp2_AO/venv/lib/python3.10/site-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
fig, ax = plt.subplots(figsize=(30,30))
ax.set_title('Correlation between variables in dataset')

filtered_data = ds.drop(['id', 'satisfaction','Customer Type', 'Type of Travel', 'Class'], axis=1)
sns.heatmap(filtered_data.corr(), vmin=-1, vmax=1, annot=True, ax=ax, cmap="icefire")
# Out:
# <AxesSubplot:title={'center':'Correlation between variables in dataset'}>
